# %%
import os
import sys

sys.path.append(os.path.abspath(".."))

import polars as pl
from pathlib import Path


from dotenv import load_dotenv
from src.utils.experiments_export import concat_experiments_to_parquet

load_dotenv()

OUPUT_PATH = Path("../latex/imgs/res/")
OUPUT_PATH.mkdir(parents=True, exist_ok=True)
OUPUT_TABLES_PATH = Path("../latex/tables/")
OUPUT_TABLES_PATH.mkdir(parents=True, exist_ok=True)
DATA_OUTPUT_PATH = Path("../data/results/")
DATA_OUTPUT_PATH.mkdir(parents=True, exist_ok=True)
INPUT_PATH = Path(os.getenv("GDRIVE_PATH"))

# %%
concat_experiments_to_parquet(
    experiment_dirs=INPUT_PATH,
    output_path=DATA_OUTPUT_PATH / "all_experiments.parquet",
    rebalance_exper=True,
    min_rebalance=7,
    keep_min_exactly=True,
)
# Out:
# Unfinished experiments found (SKIPPED):
#  - 8_agents/1751469804_oligopoly_setting_8_firms_P1
#  - 8_agents/1751476073_oligopoly_setting_8_firms_P1
# -----> Missing experiment runs on: is_synthetic=True, is_symmetric=True, num_agents=8 for prefix_type=P1 and alpha=3.2 (only 5 runs)
# -----> Missing experiment runs on: is_synthetic=True, is_symmetric=True, num_agents=8 for prefix_type=P1 and alpha=10 (only 5 runs)
# -----> Missing experiment runs on: is_synthetic=True, is_symmetric=True, num_agents=8 for prefix_type=P2 and alpha=10 (only 5 runs)
#
# Total incomplete groups: 1
# Rebalancing will be done only on complete groups.
# Final runs count by (is_synthetic, is_symmetric, num_agents, alpha, agent_prefix_type):
# is_synthetic=True, is_symmetric=False, num_agents=2:
#   alpha=1.0, prefix=P1 => runs: 7
#   alpha=1.0, prefix=P2 => runs: 7
#   alpha=3.2, prefix=P1 => runs: 7
#   alpha=3.2, prefix=P2 => runs: 7
#   alpha=10.0, prefix=P1 => runs: 7
#   alpha=10.0, prefix=P2 => runs: 7
#
# is_synthetic=True, is_symmetric=True, num_agents=1:
#   alpha=1.0, prefix=OTHER => runs: 2
#   alpha=3.2, prefix=OTHER => runs: 2
#   alpha=10.0, prefix=OTHER => runs: 2
#
# is_synthetic=True, is_symmetric=True, num_agents=2:
#   alpha=1.0, prefix=P1 => runs: 7
#   alpha=1.0, prefix=P2 => runs: 7
#   alpha=3.2, prefix=P1 => runs: 7
#   alpha=3.2, prefix=P2 => runs: 7
#   alpha=10.0, prefix=P1 => runs: 7
#   alpha=10.0, prefix=P2 => runs: 7
#
# is_synthetic=True, is_symmetric=True, num_agents=3:
#   alpha=1.0, prefix=P1 => runs: 7
#   alpha=1.0, prefix=P2 => runs: 7
#   alpha=3.2, prefix=P1 => runs: 7
#   alpha=3.2, prefix=P2 => runs: 7
#   alpha=10.0, prefix=P1 => runs: 7
#   alpha=10.0, prefix=P2 => runs: 7
#
# is_synthetic=True, is_symmetric=True, num_agents=4:
#   alpha=1.0, prefix=P1 => runs: 7
#   alpha=1.0, prefix=P2 => runs: 7
#   alpha=3.2, prefix=P1 => runs: 7
#   alpha=3.2, prefix=P2 => runs: 7
#   alpha=10.0, prefix=P1 => runs: 7
#   alpha=10.0, prefix=P2 => runs: 7
#
# is_synthetic=True, is_symmetric=True, num_agents=5:
#   alpha=1.0, prefix=P1 => runs: 7
#   alpha=1.0, prefix=P2 => runs: 7
#   alpha=3.2, prefix=P1 => runs: 7
#   alpha=3.2, prefix=P2 => runs: 7
#   alpha=10.0, prefix=P1 => runs: 7
#   alpha=10.0, prefix=P2 => runs: 7
#
# Rebalanced dataset size: 203400 rows
# Saved concatenated parquet file with 203400 rows to ..\data\results\all_experiments.parquet

# %%
df = pl.read_parquet(DATA_OUTPUT_PATH / "all_experiments.parquet")
df
# Out:
# shape: (203_400, 40)
# ┌────────────┬────────────┬────────────┬────────┬───┬────────┬────────────┬────────────┬───────────┐
# │ experiment ┆ experiment ┆ num_agents ┆ agent  ┆ … ┆ profit ┆ market_dat ┆ is_symmetr ┆ is_synthe │
# │ _timestamp ┆ _name      ┆ ---        ┆ ---    ┆   ┆ ---    ┆ a          ┆ ic         ┆ tic       │
# │ ---        ┆ ---        ┆ i64        ┆ str    ┆   ┆ f64    ┆ ---        ┆ ---        ┆ ---       │
# │ str        ┆ str        ┆            ┆        ┆   ┆        ┆ str        ┆ bool       ┆ bool      │
# ╞════════════╪════════════╪════════════╪════════╪═══╪════════╪════════════╪════════════╪═══════════╡
# │ 1750960646 ┆ monopoly_s ┆ 1          ┆ Firm A ┆ … ┆ 17.88  ┆ - My       ┆ true       ┆ true      │
# │            ┆ etting     ┆            ┆        ┆   ┆        ┆ price: 2.5 ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - My       ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ quantity … ┆            ┆           │
# │ 1750960646 ┆ monopoly_s ┆ 1          ┆ Firm A ┆ … ┆ 0.62   ┆ - My       ┆ true       ┆ true      │
# │            ┆ etting     ┆            ┆        ┆   ┆        ┆ price: 3.5 ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - My       ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ quantity … ┆            ┆           │
# │ 1750960646 ┆ monopoly_s ┆ 1          ┆ Firm A ┆ … ┆ 0.1    ┆ - My       ┆ true       ┆ true      │
# │            ┆ etting     ┆            ┆        ┆   ┆        ┆ price: 4.0 ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - My       ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ quantity … ┆            ┆           │
# │ 1750960646 ┆ monopoly_s ┆ 1          ┆ Firm A ┆ … ┆ 44.04  ┆ - My       ┆ true       ┆ true      │
# │            ┆ etting     ┆            ┆        ┆   ┆        ┆ price: 1.5 ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - My       ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ quantity … ┆            ┆           │
# │ 1750960646 ┆ monopoly_s ┆ 1          ┆ Firm A ┆ … ┆ 54.83  ┆ - My       ┆ true       ┆ true      │
# │            ┆ etting     ┆            ┆        ┆   ┆        ┆ price:     ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ 1.75       ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - My       ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ quantity…  ┆            ┆           │
# │ …          ┆ …          ┆ …          ┆ …      ┆ … ┆ …      ┆ …          ┆ …          ┆ …         │
# │ 1751380745 ┆ oligopoly_ ┆ 4          ┆ Firm D ┆ … ┆ 7.17   ┆ - My       ┆ true       ┆ true      │
# │            ┆ setting_4_ ┆            ┆        ┆   ┆        ┆ price:     ┆            ┆           │
# │            ┆ firms_P2   ┆            ┆        ┆   ┆        ┆ 12.71      ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - Competit ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ or…        ┆            ┆           │
# │ 1751380745 ┆ oligopoly_ ┆ 4          ┆ Firm D ┆ … ┆ 7.16   ┆ - My       ┆ true       ┆ true      │
# │            ┆ setting_4_ ┆            ┆        ┆   ┆        ┆ price:     ┆            ┆           │
# │            ┆ firms_P2   ┆            ┆        ┆   ┆        ┆ 12.69      ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - Competit ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ or…        ┆            ┆           │
# │ 1751380745 ┆ oligopoly_ ┆ 4          ┆ Firm D ┆ … ┆ 7.12   ┆ - My       ┆ true       ┆ true      │
# │            ┆ setting_4_ ┆            ┆        ┆   ┆        ┆ price:     ┆            ┆           │
# │            ┆ firms_P2   ┆            ┆        ┆   ┆        ┆ 12.67      ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - Competit ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ or…        ┆            ┆           │
# │ 1751380745 ┆ oligopoly_ ┆ 4          ┆ Firm D ┆ … ┆ 7.19   ┆ - My       ┆ true       ┆ true      │
# │            ┆ setting_4_ ┆            ┆        ┆   ┆        ┆ price:     ┆            ┆           │
# │            ┆ firms_P2   ┆            ┆        ┆   ┆        ┆ 12.75      ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - Competit ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ or…        ┆            ┆           │
# │ 1751380745 ┆ oligopoly_ ┆ 4          ┆ Firm D ┆ … ┆ 7.21   ┆ - My       ┆ true       ┆ true      │
# │            ┆ setting_4_ ┆            ┆        ┆   ┆        ┆ price:     ┆            ┆           │
# │            ┆ firms_P2   ┆            ┆        ┆   ┆        ┆ 12.76      ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ - Competit ┆            ┆           │
# │            ┆            ┆            ┆        ┆   ┆        ┆ or…        ┆            ┆           │
# └────────────┴────────────┴────────────┴────────┴───┴────────┴────────────┴────────────┴───────────┘
